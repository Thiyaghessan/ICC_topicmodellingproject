# %%
#before you commence this process, be sure to have mallet installed and built using Apache Ant
#http://mallet.cs.umass.edu/download.php
#https://programminghistorian.org/en/lessons/topic-modeling-and-mallet
#https://ant.apache.org/manual/install.html
#import the necessary functions 
import warnings
import datetime
import matplotlib
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import re
from nltk.tokenize import RegexpTokenizer
from nltk.stem import WordNetLemmatizer
from os import listdir
from os.path import isfile, join
import os
warnings.filterwarnings(action='ignore', category=UserWarning, module='gensim')
from gensim import corpora
from gensim.corpora import Dictionary
from gensim.models.wrappers import LdaMallet
from gensim.test.utils import common_corpus
from gensim.models.ldamodel import LdaModel
from gensim.models.coherencemodel import CoherenceModel

# %%
#define paths and variables
KUNARAC = "Kunarac"
BRIMA = "Brima"
BEMBA = "Bemba"
ALL_CASES = "All Cases"
VICTIMS = "victims"
JUDGEMENTS = "judgements"
WITNESSES = "Witnesses"
ALL_DOCS = "alldocs"
DEF_ITERATIONS = 1000
DEF_TOPICS = 10
os.environ['MALLET_HOME'] = "C:\\mallet"
PATH_TO_MALLET = "C:\\mallet\\bin\\mallet"
PATH_TO_TXT_MODELS = "C:\\results\\"
DATA_PATH = "C:\\data\\"
STOP_WORDS_PATH = "C:\\stopwords\\updated_stop_words.txt"
name = ALL_CASES
case = ALL_DOCS
processed_folders_path = "C:\\processedfolder"

# %%
SPECIAL_WORDS = ["was", "us", "as", "less", "has", "media", "Serbs", "muslims", "raped", "man", "commander", "worked",
                 "men", "does", "gave", "happened", "commander", "heard", "judes", "fo"]

stop_words = [[token.strip("\n") for token in open(STOP_WORDS_PATH, "r")], "è", "ñ", "á", "š", "â", "ý", "ž", "û", "ê", "ë", "õ", "ï", "ó", "þ", "ä", "ü", "î", "é", "ô", "ö", "ii", "mr", "eng", "alex-tamba-brima", "kunarac", "tf1", "pp", "icc", "witness", "wt", "steiner", "pppp", "presiding", "otp", "pursuant", "page", "judge", "honour", "scsl", "trial", "musa", "freetown", "redacted"]

# %%
def get_files(dir_path):
    """
    this method gets all the files in a folder and returns them as a list of documents
    :param dir_path: the path to the files
    :return: documents listed
    """
    # get all files in path
    file_names = [name for name in listdir(dir_path) if isfile(join(dir_path, name))]
    # open all files in directory
    all_files = []
    for file_name in file_names:
        print(file_name)
        n_file = open(dir_path + "\\" + file_name, "r", errors='ignore').readlines()
        all_files.append(n_file)
    return all_files

# %%
def discard_enumeration(file_list):
    """
    in case the file is enumerated (all lines start with numbers, we would want to discard them)
    in addition, it discards the \n in the end of the file.
    It also discards "procedural" line such as "open session" declarations.
    If the data is not enumerated, the files won't be changed.
    :param files: the data files  files to discard the enumeration from
    :return: the list of the files without the line numbers
    """
    new_files = []
    for file in file_list:
        if file is not None:
            lines = []
            i = 0
            for i in range(len(file)):
                line = file[i].lower()
                # delete lines announcing blank pages
                if line == "Blank page inserted to ensure pagination corresponds between the French and":
                    line = file[i+2].lower()
                if "open session" not in line:
                    if not ("ENG" in line and "CT" in line):
                        line = line.split(" ")
                        if line[0] != '\n':
                            if line[0].isdigit():
                                line = line[1:]
                    lines.append(" ".join(line))
            new_files.append(lines)
    return new_files

# %%
def tokenize_files(file_list):
    """
    creating tokenized lists from the lines of the documents.
    :param file_list:
    :return:
    """
    tokenizer = RegexpTokenizer(r'\w+')
    tokenized = []
    for file in file_list:
        t_file = ""
        for line in file:
            t_file += line
        t_file = tokenizer.tokenize(t_file)
        t_file = [word.lower() for word in t_file]
        tokenized.append(t_file)
    return tokenized

# %%
def basic_NER(file_list):
    """
    A very basic and manual NER for the specific files we worked on.
    The function scans the file and looks for specific characters in the case that appear in more than one name
    and join them under a pre-defined name.
    :param file_list: the data in process
    :return: the list of files, with the specific names replaced.
    """
    names = {"radomir": "kovac", "klanfa" : "kovac",
             "zaga" : "kunarac", "dragoljub":"kunarac", "zoran" : "vukovic",
              "gullit": "alex-tamba-brima",
             "saj": "musa"}
    double_names = {"rojoj": "pass", "sierra": "leone", "buk": "bijela",
                    "cerova": "ravan", "lepa": "brena", "kp": "dom",
                    "junior": "lion"}
    triple_names = {"santigie": ["borbor", "kanu"]}
    window = 3
    new_files = []
    i = 0
    for file in file_list:
        new_file = []
        while i < len(file):
            word = file[i].lower()
            word_win = file[i - window:i + window]
            word_win = [w.lower() for w in word_win]
            if word == "leone":
                    new_file.append("sierra-leone")
            elif word in names:
                new_file.append(names[word])
            elif word in double_names:
                if double_names[word] in file[i-window:i+window] or "leonean" in file[i-window:i+window]:
                    new_file.append(word + "-" + double_names[word])
                    i += 1
            elif word in triple_names:
                new_file.append(word + "-" + triple_names[word][0] + "-" + triple_names[word][1])
                if triple_names[word][0] in word_win:
                    if triple_names[word][1] in word_win:
                        i += 2
                    else:
                        i += 1
            elif word == "alex":
                if 'brima' in word_win:
                    new_file.append("alex-tamba-brima")
                    i += 2
            elif word == "tamba":
                new_file.append("alex-tamba-brima")
                i+=1
            elif word == "ibrahim":
                if 'bazzy' in word_win or 'kamara' in word_win:
                    new_file.append("brima-kamara")
                    i += 2
            elif word == "sam" or word == "bockarie":
                if "bockarie" in word_win:
                    new_file.append("mosquito")
                    i += 1
            elif word == 'bazzy':
                new_file.append("brima-kamara")
                i += 1
            elif word == "brima":
                if 'et' and 'al' in word_win:
                    i += 2
            else:
                new_file.append(word)
            i+=1
        new_files.append(new_file)
        i = 0
    return new_files

# %%
def lemmatize_files(file_list):
    """
    This function
    :return:
    """
    # lematize all files
    lemmatizer = WordNetLemmatizer()
    lemmatized_files = []
    for file in file_list:
        new_file = []
        for word in file:
            if word.lower() in SPECIAL_WORDS:
                word = special_lemmatizer(word)
            else:
                word = lemmatizer.lemmatize(word)
            new_file.append(word)
        lemmatized_files.append(new_file)
    return lemmatized_files

# %%
def special_lemmatizer(word):
    """
    lemmatizer for the words that are wrongly lemmatized in the WORDNETLEMMATIZER.
    :param word: the word to lemmatize
    :return: the right form of the word after lemmatizing
    """
    word = word.lower()
    if word.lower() == "raped":
        return "rape"
    if word.lower() == "redaction":
        return "redacted"
    if word.lower() == "men":
        return "man"
    if word == "was":
        return "is"
    if word == "commander":
        return "command"
    if word == "worked":
        return "work"
    if word == "muslims":
        return "muslim"
    if word == "Serbs":
        return "Serb"
    if word == "men":
        return "man"
    if word == "gave":
        return "give"
    if word == "does" or word == "doent":
        return "do"
    if word == "happened":
        return "happen"
    if word == "vukovi":
        return "vukovic"
    if word == "herad":
        return "hear"
    if word == "fo":
        return "foca"
    if word =="dragoljub":
        return ""
    else:
        return word

# %%
def clean(files_list, stop_words):
    """
    This method deletes all stop words from the files
    :param files_list: the files to clean
    :param stop_words the list of words to discard
    :return:
    """
    clean_files = []
    for file in files_list:
        c_file = []
        for word in file:
            if word.lower() not in stop_words and "ÿ" not in word and not word.isdigit():
                c_file.append(word.lower())
        clean_files.append(c_file)
    return clean_files

# %%
def count_freq(files_list):
    """
    This function anlyzes and counts the frequencies of all the words in the data.
    This way, we could decide of the threshold for deleting too-frequent words from the data.
    :param files_list:
    """
    frequencies = {}
    for file in files_list:
        for word in file:
            if word not in frequencies:
                frequencies[word] = 1
            else:
                frequencies[word] += 1
    x = sorted((value, key) for (key, value) in frequencies.items())
    x.reverse()
    # # printing the actual frequencies
    # for w in x:
    #     print(w)

# %%
def check_words(file_list):
    all = {}
    for file in file_list:
        for line in file:
            line = line.split(" ")
            for word in line:
                word = word.strip()
                word = re.sub('[!#?.,-\\\]', '', word)
                word = word.title()
                if str(word) not in all:
                    all[str(word)] = 1
                else:
                    all[str(word)] += 1
    all = sorted((value, key) for (key, value) in all.items())
    all.reverse()
    print(all)
    print(len(all))
    return all

# %%
def create_data(path):
    """
    this method contains the process of cleaning and creating the data.
    :return: processed files.
    """
    file_list = get_files(path)
    file_list = discard_enumeration(file_list)
    file_list = tokenize_files(file_list)
    file_list = basic_NER(file_list)
    file_list = lemmatize_files(file_list)
    file_list = clean(file_list, stop_words)
    # freq = count_freq(file_list)
    return file_list

# %%
def create_lda_model(file_path, case="default", num_topics=10, iterations=5000, save=True):
    """
    create LDA model from a pre-processed data.
    @:param file_path: the path to the data file
    @:param num_topics: number of topics for the model
    @:param iterations: number of iterations the model will run
    @:param case: name of the case or data files we're working on, for saving
    @:param save: whether to save the model
    :return: the ready lda model
    """
    # create doc to term matrices
    dictionary = corpora.Dictionary(file_path)
    corpus = [dictionary.doc2bow(file) for file in file_path]
    model = LdaMallet(PATH_TO_MALLET, corpus=corpus, num_topics=num_topics,
                      id2word=dictionary, iterations=iterations)
    # get the date and time for saving
    now = datetime.datetime.now()
    if save:
        serial_name = name + "_" + str(num_topics) + "_topics_" + str(now.hour) + "h" + str(now.minute) + "m"
        print("saving as " + serial_name)
        print(" ")
        model.save(serial_name)
        save_topics_to_text(model, serial_name)
    return model

# define name for your intended output file name (eg I name = "Bemba", so the output file will be named Bemba)

# %%
def save_topics_to_text(lda_model, name):
    """
    This function saves the topics of a model in the wanted format, on a txt file named as the model
    :param lda_model: the model
    :param name: the name of the saved txt file
    :return:
    """
    topics = lda_model.print_topics(num_words=20)
    file = open(PATH_TO_TXT_MODELS + case + "\\" + name + ".txt", 'w+')
    for topic in topics:
        file.write("Topic " + str(topic[0]) + ": \n\n")
        words = topic[1].split("+")
        for i in range(len(words)):
            word = words[i].split("*")
            word = word[1].strip()
            word = word.replace("\"", "")
            file.write(word)
            if i < len(words)-1:
                file.write(", ")
            else:
                file.write(".")
            if i == 9:
                file.write("\n")
        file.write("\n\n")

# %%
ALL_CASE_DATA = create_data(DATA_PATH)
# Out:
# 01.05.12_CAR‐V20‐PPPP‐0001_FPVD2.txt
# 01.06.11_CAR-OTP-PPPP-0209_MPWX5.txt
# 01.07.05_TF1-072_MPWD1.txt
# 01.07.05_TF1-072_MPWJ1.txt
# 01.07.05_TF1-072_MPWX1.txt
# 01.07.11_CAR-OTP-PPPP-0169_MPWD1.txt
# 01.08.06_DAB-023_MDWD2.txt
# 01.11.11_CAR-OTP-PPPP-0047_MPWX5.txt
# 01.11.13-CAR-D04-PPPP-0054_MDWX2.txt
# 01.11.13-CAR-D04-PPPP-0054_MVWD1.txt
# 01.12.10_CAR-OTP-PPPP-0022_FPVD1.txt
# 02.05.12_CAR-V20-PPPP-0001_FPVD3.txt
# 02.05.12_CAR-V20-PPPP-0001_FPVX4.txt
# 02.08.06_DBK-063_MDWD1.txt
# 02.08.06_DBK-063_MDWX1.txt
# 02.09.11_CAR-OTP-PPPP-0178_MPWD2.txt
# 02.09.11_CAR-OTP-PPPP-0178_MPWX3.txt
# 02.09.13-CAR-D04-PPPP-0030_FDWD2.txt
# 02.09.13-CAR-D04-PPPP-0030_FDWX1.txt
# 02.10.06_DAB-033_MDWD2.txt
# 02.10.06_DAB-033_MDWJ1.txt
# 02.10.06_DAB-033_MDWX2.txt
# 02.10.06_DAB-059_MDWX2.txt
# 02.10.06_DAB-137_MDWD1.txt
# 02.11.11_CAR-OTP-PPPP-0047_MPWX6.txt
# 03.02.11_CAR-OTP-PPPP-0082_FPVX1.txt
# 03.03.13-CAR-D04-PPPP-0019_MDWX3.txt
# 03.04.00_procedural discussion on witnesses.docx
# 03.04.00_W75_FPVD2.txt
# 03.04.00_W75_FPVX1.txt
# 03.05.00_W185_FPWD1.txt
# 03.05.00_W185_FPWX1.txt
# 03.05.00_W48_FPVD1.txt
# 03.05.00_W48_FPVX1.txt
# 03.05.12_CAR‐V20‐PPPP‐0001_FPVX1.txt
# 03.07.06_Brima_MDAX8.txt
# 03.09.12-CAR-D04-PPPP-0059_MDED1.txt
# 03.09.12-CAR-D04-PPPP-0059_MDED2.txt
# 03.09.13-CAR-D04-PPPP-0030_FDWX2.txt
# 03.09.13-CAR-D04-PPPP-0030_FVWD1.txt
# 03.10.05_Bangura_FPED1.txt
# 03.10.05_Bangura_FPEX1.txt
# 03.10.06_DAB-137_MDWX1.txt
# 03.10.06_DAB-147_MDWD1.txt
# 03.10.06_DAB-147_MDWD2.txt
# 03.10.06_DAB-147_MDWX1.txt
# 03.10.06_DBK-037_MDWD1.txt
# 03.10.11_CAR-OTP-PPPP-0065_MPWD1.txt
# 03.11.11_CAR-OTP-PPPP-0047_MPWX7.txt
# 03.12.12-CAR-D04-PPPP-0066_MDWX1.txt
# 04.03.11_CAR‐OTP‐PPPP‐0006_MPED1.txt
# 04.03.13-CAR-D04-PPPP-0019_MDWX4.txt
# 04.04.00_W75_FPVD2.txt
# 04.04.00_W75_FPVX2.txt
# 04.04.00_W87_FPVD1.txt
# 04.04.00_W87_FPVX1.txt
# 04.05.00_W192_FPWD1.txt
# 04.05.11_CAR‐OTP‐PPPP‐0009_MPED2.txt
# 08.03.05_TF1-024_MPWX2.txt
# 08.03.05_TF1-277_MPWD1.txt
# 08.03.05_TF1-277_MPWX1.txt
# 08.04.05_TF1-083_MPWD1.txt
# 08.04.05_TF1-083_MPWJ1.txt
# 08.04.05_TF1-083_MPWX1.txt
# 08.04.05_TF1-227_MPWD1.txt
# 08.04.05_TF1-320_MPWD1.txt
# 08.04.05_TF1-320_MPWX1.txt
# 08.04.13-CAR-D04-PPPP-0021_MDWD1.txt
# 08.05.12_CAR‐V20‐PPPP‐0002_MPWX1.txt
# 08.05.13-CAR-D04-PPPP-0056_MDWX1.txt
# 08.06.06_Brima_MDAD4.txt
# 08.06.11_CAR-OTP-PPPP-0209_MPWX6.txt
# 08.07.05_TF1-180_MPWD1.txt
# 08.07.05_TF1-180_MPWX1.txt
# 08.09.06_DAB-084_MDWD1.txt
# 08.09.06_DAB-084_MDWX1.txt
# 08.09.06_DAB-092_MDWD1.txt
# 08.09.06_DAB-092_MDWX1.txt
# 08.09.06_DAB-107_MDWD1.txt
# 08.09.06_DAB-129_MDWD1.txt
# 08.09.11_CAR-OTP-PPPP-0033_MPWD1.txt
# 08.09.11_CAR-OTP-PPPP-0178_MPWX6.txt
# 08.11.11_CAR‐OTP‐PPPP‐0031_MPWX2.txt
# 08.11.12-CAR-D04-PPPP-0048_MDWD2.txt
# 08.11.12-CAR-D04-PPPP-0048_MVWD1.txt
# 08.11.12-CAR-D04-PPPP-0048_MVWD2.txt
# 09.03.05_TF1-023_FPVD1.txt
# 09.03.05_TF1-277_MPWX2.txt
# 09.04.13-CAR-D04-PPPP-0021_MDWD2.txt
# 09.05.11_CAR‐OTP‐PPPP‐0009_MPEX5.txt
# 09.06.11_CAR-OTP-PPPP-0110_FPWD1.txt
# 09.10.06_DBK-012_MDWX2.txt
# 09.10.06_DBK-129_MDWD1.txt
# 09.10.06_DBK-129_MDWX1.txt
# 10.03.05_TF1-023_FPVD2.txt
# 10.04.13-CAR-D04-PPPP-0021_MDWX1.txt
# 10.05.11_CAR‐OTP‐PPPP‐0009_MPEX1.txt
# 10.06.11_CAR-OTP-PPPP-0110_FPWD2.txt
# 10.06.11_CAR-OTP-PPPP-0110_FPWX3.txt
# 10.07.00_Kunarac_MDAX1.txt
# 10.07.06_DBK-050_MDWD1.txt
# 10.07.06_DBK-050_MDWD2.txt
# 10.07.06_DBK-050_MDWJ1.txt
# 10.07.06_DBK-050_MDWX1.txt
# 10.07.06_DBK-096_MDWD1.txt
# 10.07.06_DBK-096_MDWX1.txt
# 10.07.06_DBK-103_MDWD1.txt
# 10.07.06_DBK-103_MDWJ1.txt
# 10.07.06_DBK-103_MDWX1.txt
# 10.10.05_Massaquoi_MPWD2.txt
# 10.10.05_Massaquoi_MPWX1.txt
# 10.10.06_DBK-131_MDWD1.txt
# 10.10.06_DBK-131_MDWX1.txt
# 10.11.00_DeGrave_MPEJ1.txt
# 10.11.00_DeGrave_MPEX1.txt
# 10.11.00_Dunjic_MPED1.txt
# 10.11.00_Dunjic_MPEX1.txt
# 11.01.11_CAR‐OTP‐PPPP‐0087_FPVD1.txt
# 17.06.11_CAR-OTP-PPPP-0112_MPWX3.txt
# 17.06.13-CAR-D04-PPPP-0009_MDWD3.txt
# 17.06.13-CAR-D04-PPPP-0009_MVWD1.txt
# 17.07.00_WDA_MDED1.txt
# 17.07.00_WDA_MDEX1.txt
# 17.07.00_WDC_MDWD1(1).txt
# 17.07.00_WDC_MDWD1.txt
# 17.07.06_DBK-090_MDWD1.txt
# 17.07.06_DBK-090_MDWJ1.txt
# 17.07.06_DBK-090_MDWX1.txt
# 17.07.06_DBK-095_MDWD1.txt
# 17.07.06_DBK-100_FDWD1.txt
# 17.08.12_CAR-D04-PPPP-0053_MDEX1.txt
# 17.09.12-CAR-D04-PPPP-0065_MDWX2.txt
# 17.10.05_TF1-217_MPWD1.txt
# 17.10.05_TF1-217_MPWD2.txt
# 17.10.05_TF1-217_MPWX1.txt
# 17.10.06_Prins_MDED1.txt
# 17.10.12-CAR-D04-PPPP-0057_MDWD1.txt
# 17.10.12-CAR-D04-PPPP-0057_MDWX1.txt
# 18.02.11_CAR-OTP-PPPP-0042_MPWX7.txt
# 18.03.11_CAR-OTP-PPPP-0119_FPWD1.txt
# 18.03.13-CAR-D04-PPPP-0045_MDWX2.txt
# 18.04.05_TF1-053_MPWD1.txt
# 18.04.05_TF1-253_MPWX1.txt
# 18.05.00_W175_FPVD1.txt
# 18.05.00_W205_FPVD2.txt
# 18.05.00_W205_FPVX1.txt
# 18.05.05_TF1-334_MPWD3.txt
# 18.05.11_CAR-OTP-PPPP-0063_MPWD2.txt
# 18.05.16_Defence Sentencing Hearing.txt
# 18.05.16_Prosecution Sentencing Hearing.txt
# 18.05.16_Victim_s Counsel Sentencing Hearing.txt
# 18.06.13-CAR-D04-PPPP-0004_MDWD1.txt
# 18.07.00_Blagojevic_MDWD1.txt
# 18.07.00_Blagojevic_MDWD2.txt
# 18.07.00_Blagojevic_MDWX1.txt
# 18.07.00_Djurovic_MDWD1.txt
# 18.07.00_Djurovic_MDWX1.txt
# 18.07.00_Markovic_MDWD1.txt
# 18.07.00_Markovic_MDWX1.txt
# 18.07.00_Mastillo_MDWD1.txt
# 18.07.05_TF1-113_FPWD1.txt
# 18.07.05_TF1-113_FPWX1.txt
# 18.07.05_TF1-114_MPWX1.txt
# 18.07.06_DBK-086_MDWD1.txt
# 18.07.06_DBK-086_MDWX1.txt
# 18.07.06_DBK-102_MDWD1.txt
# 18.07.06_DBK-104_MDWD1.txt
# 18.07.06_DBK-104_MDWX1.txt
# 18.07.06_DBK-105_MDWD1.txt
# 18.07.06_DBK-105_MDWD2.txt
# 18.07.06_DBK-105_MDWX1.txt
# 18.09.00_WDH_FDWD1.txt
# 18.09.00_WDH_FDWD2.txt
# 18.09.00_WDH_FDWX1.txt
# 18.09.00_WDI_FDWD1.txt
# 18.09.00_WDI_FDWX1.txt
# 18.09.00_WDV_FDWD1.txt
# 18.09.00_WDV_FDWX1.txt
# 18.09.06_DBK-096_MDWD1.txt
# 18.09.06_DBK-110_MDWD1.txt
# 18.09.06_DBK-110_MDWX1.txt
# 18.09.06_DBK-111_MDWD1.txt
# 19.11.12-CAR-D04-PPPP-0049_MDWD1.txt
# 19.11.13-CAR-CHM-PPPP-0001_MDWX2.txt
# 20.03.00_Thapa_FPED1.txt
# 20.03.00_Thapa_FPEX1.txt
# 20.03.12_CAR-OTP-PPPP-0036_MPWD3.txt
# 20.03.12_CAR-OTP-PPPP-0036_MPWX2.txt
# 20.03.12_CAR-OTP-PPPP-0036_MPWX4.txt
# 20.03.13-CAR-D04-PPPP-0045_MDWX4.txt
# 20.04.00_W78_MPWD2.txt
# 20.04.00_W78_MPWX1(1).txt
# 20.04.00_W78_MPWX1.txt
# 20.05.05_TF1-334_MPWD5.txt
# 20.05.11_CAR-OTP-PPPP-0063_MPWD6.txt
# 20.06.05_TF1-334_MPWX3.txt
# 20.06.06_Brima_MDAX2.txt
# 20.06.07_Judgement_Transcript.txt
# 20.06.13-CAR-D04-PPPP-0004_MDWX2.txt
# 20.06.13-CAR-D04-PPPP-0004_MVWD1.txt
# 20.06.13-CAR-D04-PPPP-0004_MVWD2.txt
# 20.07.05_TF1-045_MPWX1.txt
# 20.07.06_DAB-080_FDWD1.txt
# 20.07.06_DAB-080_FDWX1.txt
# 20.07.06_DAB-081_MDWD1.txt
# 20.07.06_DAB-085_MDWD1.txt
# 20.07.06_DAB-085_MDWD2.txt
# 20.07.06_DAB-085_MDWJ1.txt
# 20.07.06_DAB-085_MDWX1.txt
# 20.08.13-CAR-D04-PPPP-0023_MDWD1.txt
# 20.09.00_WDP_MDWD2.txt
# 20.09.00_WDP_MDWD3.txt
# 20.09.00_WDP_MDWX1.txt
# 20.09.00_WDQ_MDWD1.txt
# 20.09.00_WDQ_MDWX1.txt
# 20.09.00_WDR_FDWD1.txt
# 20.09.00_WDR_FDWD2.txt
# 20.09.00_WDR_FDWX1.txt
# 20.09.05_TF1-167_MPWX2.txt
# 20.09.06_DAB-095_MDWD1.txt
# 20.09.12-CAR-D04-PPPP-0007_MDWX1.txt
# 20.10.06_Prins_MDEX2.txt
# 20.10.11_CAR‐OTP‐PPPP‐0151_MPWX3.txt
# 20.11.12-CAR-D04-PPPP-0049_MDWD2.txt
# 20.11.12-CAR-D04-PPPP-0049_MDWX1.txt
# 20.11.13-CAR-CHM-PPPP-0001_MDWX3.txt
# 21.01.11_CAR-OTP-PPPP-0023_MPVD1.txt
# 21.02.11_CAR-OTP-PPPP-0073_MPWD7.txt
# 21.03.00_W33_FPWD1.txt
# 21.03.00_W33_FPWX1.txt
# 21.03.11_CAR-OTP-PPPP-0119_FPWD2.txt
# 21.03.13-CAR-D04-PPPP-0045_MDWX5.txt
# 21.03.13-CAR-D04-PPPP-0045_MVWD1.txt
# 21.03.16_Judgement Summary.txt
# 21.03.16_Judgement_Cumulative Conditions.txt
# 21.03.16_Judgement_Facts.txt
# 21.03.16_Judgement_Issues of Evidence.txt
# 21.03.16_Judgement_Law.txt
# 21.03.16_Judgement_Legal Findings.txt
# 21.03.16_Judgement_Overview.txt
# 21.03.16_Judgement_Scope and Notice of Charges.txt
# 21.03.16_Judgement_SEPARATE OPINION OF JUDGE KUNIKO OZAKI.txt
# 23.02.11_CAR-OTP-PPPP-0073_MPWD2.txt
# 23.03.00_Avdic_MPWX2.txt
# 23.03.00_W52_MPWD1.txt
# 23.03.00_W52_MPWX1.txt
# 23.03.11_CAR-OTP-PPPP-0119_FPWX5.txt
# 23.03.11_CAR-OTP-PPPP-0119_FPWX7.txt
# 23.04.13-CAR-D04-PPPP-0039_MDWX2.txt
# 23.05.00_W61_FPWX2.txt
# 23.05.05_TF1-334_MPWD6.txt
# 23.05.11_CAR-OTP-PPPP-0063_MPWD8.txt
# 23.05.11_CAR-OTP-PPPP-0063_MPWX9.txt
# 23.06.05_TF1-004_MPWD1.txt
# 23.06.05_TF1-004_MPWX1.txt
# 23.08.11_CAR-OTP-PPPP-0173_MPWD2.txt
# 23.08.13-CAR-D04-PPPP-0026_MDWX1.txt
# 23.08.13-CAR-D04-PPPP-0026_MVWD1.txt
# 23.09.05_TF1-153_MPWD2.txt
# 23.09.05_TF1-153_MPWJ1.txt
# 23.09.05_TF1-153_MPWX1.txt
# 23.09.11_CAR-OTP-PPPP-0032_MPWD1.txt
# 23.09.11_CAR-OTP-PPPP-0032_MPWX2.txt
# 23.10.00_W87_FPVD1.txt
# 23.10.00_W87_FPVX1.txt
# 23.10.12-CAR-D04-PPPP-0064_MDWD2.txt
# 23.10.12-CAR-D04-PPPP-0064_MDWX2.txt
# 23.10.12-CAR-D04-PPPP-0064_MVWD1.txt
# 23.10.14-CAR-OTP-PPPP-0169_MPWX1.txt
# 23.10.14-CAR-OTP-PPPP-0169_MVWD2.txt
# 23.11.12-CAR-D04-PPPP-0049_MDWX4.txt
# 23.11.12-CAR-D04-PPPP-0049_MVWD1.txt
# 24.02.11_CAR-OTP-PPPP-0073_MPWD3.txt
# 24.02.11_CAR-OTP-PPPP-0073_MPWX4.txt
# 24.03.11_CAR-OTP-PPPP-0119_FPWX6.txt
# 24.03.11_CAR‐OTP‐PPPP‐0222_MPED1.txt
# 24.04.13-CAR-D04-PPPP-0039_MDWX3.txt
# 24.04.13-CAR-D04-PPPP-0039_MVWD1.txt
# 24.05.00_Alic_MPWD1.txt
# 24.05.00_Alic_MPWD2.txt
# 24.05.00_Alic_MPWX1.txt
# 24.05.00_Nogo_MPED1.txt
# 24.05.00_Nogo_MPED2.txt
# 24.05.00_Nogo_MPEX1.txt
# 24.05.05_TF1-334_MPWD7.txt
# 24.05.11_CAR-OTP-PPPP-0063_MPWX7.txt
# 24.06.05_TF1-122_MPWD1.txt
# 24.06.05_TF1-122_MPWX1.txt
# 24.06.13-CAR-D04-PPPP-0006_MDWD2.txt
# 24.06.13-CAR-D04-PPPP-0006_MDWX3.txt
# 24.06.13-CAR-D04-PPPP-0006_MVWD1.txt
# 24.06.13-CAR-D04-PPPP-0006_MVWD2.txt
# 24.07.00_WDD_MDWD1.txt
# 24.07.00_WDD_MDWD2.txt
# 24.07.00_WDD_MDWX1.txt
# 24.07.00_WDE_MDWD1.txt
# 24.07.00_WDE_MDWD2.txt
# 24.07.00_WDE_MDWX1.txt
# 24.07.06_DAB-088_MDWD1.txt
# 24.07.06_DAB-088_MDWX1.txt
# 24.07.06_DAB-089_MDWD1.txt
# 24.07.06_DAB-089_MDWX1.txt
# 24.07.06_DAB-090_MDWD1.txt
# 24.07.06_DAB-090_MDWJ1.txt
# 24.07.06_DAB-090_MDWX1.txt
# 24.07.06_DAB-091_MDWD1.txt
# 24.07.06_DAB-091_MDWX1.txt
# 24.08.11_CAR-OTP-PPPP-0173_MPWD3.txt
# 24.08.11_CAR-OTP-PPPP-0173_MPWX4.txt
# 24.10.06_Prins_MDED2.txt
# 24.10.06_Prins_MDEX3.txt
# 24.10.06_Thorsen_FDED1.txt
# 24.10.06_Thorsen_FDEX1.txt
# 24.10.12-CAR-D04-PPPP-0051_MDWD1.txt
# 24.10.12-CAR-D04-PPPP-0051_MDWX1.txt
# 24.10.14-CAR-OTP-PPPP-0169_MPWX2.txt
# 25.02.11_CAR-OTP-PPPP-0073_MPWX8.txt
# 25.02.13-CAR-D04-PPPP-0019_MDWD1.txt
# 25.04.00_W95_FPVD1.txt
# 25.04.00_W95_FPVX1.txt
# 25.05.05_TF1-334_MPWD8.txt
# 25.05.11_CAR-OTP-PPPP-0063_MPWX10.txt
# 25.05.11_CAR-OTP-PPPP-0063_MPWX11.txt
# 25.06.12_a_0542_08_FPVD1.txt
# 25.06.13-CAR-D04-PPPP-0003_MDWX2.txt
# 25.07.05_TF1-157_MPWD2.txt
# 25.07.05_TF1-157_MPWX1.txt
# 25.07.06_DAB-086_MDWD1.txt
# 25.07.06_DAB-086_MDWD2.txt
# 25.07.06_DAB-086_MDWX1.txt
# 25.07.06_DAB-087_MDWD1.txt
# 25.07.06_DAB-087_MDWX1.txt
# 25.08.11_CAR-OTP-PPPP-0173_MPWX1.txt
# 25.09.06_DAB-033_MDWD1.txt
# 25.09.06_DAB-033_MDWX1.txt
# 25.09.06_DAB-096_MDWX1.txt
# 25.10.06_DBK-126_FDWD2.txt
# 25.10.06_DBK-126_FDWJ1.txt
# 25.10.06_DBK-126_FDWX1.txt
# 25.10.06_Thorsen_FDED2.txt
# 25.10.06_Thorsen_FDEJ1.txt
# 25.10.06_Thorsen_FDEX2.txt
# 25.10.12-CAR-D04-PPPP-0051_MDWX2.txt
# 26.02.13-CAR-D04-PPPP-0019_MDWD2.txt
# 26.04.00_W132_FPVD1.txt
# 26.04.00_W132_FPVD2.txt
# 26.04.00_W132_FPVX1.txt
# 26.04.00_W95_FPVD2.txt
# 26.04.00_W95_FPVX2.txt
# 26.05.11_CAR-OTP-PPPP-0209_MPWD1.txt
# 26.06.12_a_0394_08_MPVD1.txt
# 26.06.12_a_0394_08_MPVJ2.txt
# 26.07.00_Djurovic_MDWD1.txt
# 26.07.00_Djurovic_MDWD2.txt
# 26.07.00_Djurovic_MDWX1.txt
# 26.07.00_Pavlovic_MDWD1.txt
# 26.07.00_Pavlovic_MDWD2.txt
# 26.07.00_Pavlovic_MDWX1.txt
# 26.07.00_Przulj_MDWD1.txt
# 26.07.00_Przulj_MDWX1.txt
# 26.07.05_TF1-158_MPWD1.txt
# 26.07.05_TF1-158_MPWX1.txt
# 26.07.05_TF1-267_FPVD1.txt
# 26.08.11_CAR-OTP-PPPP-0173_MPWX5.txt
# 26.08.13-CAR-D04-PPPP-0025_MDWD1.txt
# 26.08.13-CAR-D04-PPPP-0025_MDWX1.txt
# 26.09.05_TF1-156_MPWD1.txt
# 26.09.05_TF1-156_MPWX1.txt
# 26.09.05_TF1-157_MPWX2.txt
# 26.09.05_TF1-184_MPWD1.txt
# 26.09.06_DAB-059_MDWD1.txt
# 26.09.06_DAB-059_MDWX1.txt
# 26.09.06_DBA-111_MDWD1.txt
# 26.09.06_DBA-111_MDWD2.txt
# 26.09.06_DBA-111_MDWX1.txt
# 26.09.11_CAR-OTP-PPPP-0032_MPWX3.txt
# 26.10.06_DBK-131_MDWD2.txt
# 26.10.06_DBK-131_MDWX3.txt
# 26.10.12-CAR-D04-PPPP-0051_MDWX3.txt
# 26.10.12-CAR-D04-PPPP-0051_MVWD1.txt
# 26.11.12-CAR-D04-PPPP-0016_MDWD1.txt
# 26.11.12-CAR-D04-PPPP-0016_MDWX1.txt
# 27.02.13-CAR-D04-PPPP-0019_MDWD3.txt
# 27.02.13-CAR-D04-PPPP-0019_MDWX1.txt
# 27.03.00_W52_MPWD2.txt
# 27.03.00_W52_MPWX2.txt
# 27.03.00_W62_FPWD1.txt
# 27.03.00_W62_FPWX1.txt
# 27.03.00_W93_FPWD1.txt
# 27.04.00_W96_FPWD1.txt
# 27.04.00_W96_FPWX1.txt
# 27.05.11_CAR-OTP-PPPP-0209_MPWD2.txt
# 27.06.05_TF1-062_MPWD1.txt
# 27.06.05_TF1-062_MPWX1.txt
# 27.06.05_TF1-076_FPVD1.txt
# 27.06.05_TF1-076_FPVX1.txt
# 27.06.05_TF1-216_MPWD1.txt
# 27.06.05_TF1-216_MPWX1.txt
# 27.07.05_TF1-179_MPWD1.txt
# 27.07.05_TF1-179_MPWX1.txt
# 27.07.05_TF1-267_FPVD2.txt
# 27.07.05_TF1-267_FPVX1.txt
# 27.08.13-CAR-D04-PPPP-0025_MDWD2.txt
# 27.08.13-CAR-D04-PPPP-0025_MDWX2.txt
# 27.08.13-CAR-D04-PPPP-0025_MVWD1.txt
# 27.09.05_TF1-184_MPWX1.txt
# 27.09.11_CAR-OTP-PPPP-0032_MPWX4.txt
# 27.10.11_CAR-OTP-PPPP-0047_MPWD1.txt
# 27.10.11_CAR-OTP-PPPP-0047_MPWD2.txt
# 27.11.12-CAR-D04-PPPP-0016_MDWX2.txt
# 28.02.11_CAR-OTP-PPPP-0073_MPWD6.txt
# 28.02.11_CAR-OTP-PPPP-0073_MPWX5.txt
# 28.02.11_CAR-OTP-PPPP-0079_FPWD1.txt
# 28.02.13-CAR-D04-PPPP-0019_MDWX2.txt
# 28.06.05_TF1-198_FPVD1.txt
# 28.06.05_TF1-198_FPVX1.txt
# 28.06.05_TF1-206_MPWD1.txt
# 28.06.05_TF1-206_MPWX1.txt
# 28.06.06_Brima_MDAX5.txt
# 28.07.06_DAB-025_MDWD1.txt
# 28.07.06_DAB-025_MDWD2.txt
# 28.07.06_DAB-025_MDWX1.txt
# 28.07.06_DAB-079_MDWD1.txt
# 28.07.06_DAB-079_MDWD2.txt
# 28.07.06_DAB-079_MDWX1.txt
# 28.08.13-CAR-D04-PPPP-0029_MDWD1.txt
# 28.08.13-CAR-D04-PPPP-0036_MDWD1.txt
# 28.08.13-CAR-D04-PPPP-0036_MDWX1.txt
# 28.08.13-CAR-D04-PPPP-0036_MVWD1.txt
# 28.09.06_DAB-095_MDWD2.txt
# 28.09.06_DAB-095_MDWJ1.txt
# 28.09.06_DAB-095_MDWX1.txt
# 28.09.06_DAB-100_MDWD1.txt
# 28.09.06_DAB-100_MDWX1.txt
# 28.09.06_DAB-109_MDWD1.txt
# 28.09.06_DAB-109_MDWD2.txt
# 28.09.06_DAB-109_MDWJ1.txt
# 28.09.06_DAB-109_MDWX1.txt
# 28.11.12-CAR-D04-PPPP-0016_MDWX3.txt
# 28.11.12-CAR-D04-PPPP-0016_MVWD1.txt
# 29.03.00_W50_FPVD1.txt
# 29.03.00_W50_FPVX1.txt
# 29.03.00_W51_FPVD1.txt
# 29.03.00_W51_FPVD2.txt
# 29.05.00_Subasic_MPWD1.txt
# 29.05.00_Subasic_MPWX1.txt
# 29.06.05_TF1-206_MPWX2.txt
# 29.06.06_Brima_MDAX6.txt
# 29.06.11_CAR-OTP-PPPP-0108_MPWX1.txt
# 29.08.11_CAR-OTP-PPPP-0173_MPWX6.txt
# 29.09.05_TF1-184_MPWX2.txt
# 29.09.06_DAB-100_MDWD2.txt
# 29.09.06_DAB-100_MDWJ1.txt
# 29.09.06_DAB-100_MDWX2.txt
# 29.09.06_DAB-156_FDVD1.txt
# 29.09.06_DAB-156_FDVJ1.txt
# 29.09.06_DAB-156_FDVX1.txt
# 29.10.12-CAR-D04-PPPP-0055_MDWD1.txt
# 29.10.12-CAR-D04-PPPP-0055_MDWX1.txt
# 29.11.10_CAR‐OTP‐PPPP‐0221_FPED1.txt
# 29.11.12-CAR-D04-PPPP-0016_MDWD2.txt
# 29.11.12-CAR-D04-PPPP-0016_MVWD2.txt
# 30.03.00_W50_FPVX2.TXT
# 30.03.00_W50_FPVX2_.docx
# 30.03.00_W75_FPVD1.docx
# 30.05.11_CAR-OTP-PPPP-0209_MPWD3.txt
# 30.06.05_TF1-019_MPWD1.txt
# 30.06.05_TF1-019_MPWX1.txt
# 30.06.06_Brima_MDAX7.txt
# 30.06.11_CAR-OTP-PPPP-0108_MPWX2.txt
# 30.08.11_CAR-OTP-PPPP-0178_MPWD1.txt
# 30.08.13-CAR-D04-PPPP-0030_FDWD1.txt
# 30.09.05_TF1-184_MPWD2.txt
# 30.09.05_TF1-184_MPWX3.txt
# 30.10.12-CAR-D04-PPPP-0055_MDWX2.txt
# 30.10.13-CAR-D04-PPPP-0054_MDWD1.txt
# 30.11.10_CAR‐OTP‐PPPP‐0221_FPED2.txt
# 30.11.10_CAR‐OTP‐PPPP‐0221_FPEX3.txt
# 30.11.12-CAR-D04-PPPP-0066_MDWD1.txt
# 31.05.11_CAR-OTP-PPPP-0209_MPWD4.txt
# 31.07.06_DAB-023_MDWD1.txt
# 31.10.11_CAR-OTP-PPPP-0047_MPWD3.txt
# 31.10.11_CAR-OTP-PPPP-0047_MPWX4.txt
# 31.10.12-CAR-D04-PPPP-0055_MVWD1.txt
# 31.10.13-CAR-D04-PPPP-0054_MDWD2.txt
# 31.10.13-CAR-D04-PPPP-0054_MDWX1.txt
# CONCURRING OPINION.txt
# CONSIDERATIONS.txt
# CONTEXT.txt
# CUMULATIVE CONVICTIONS.txt
# DEFECTS.txt
# DISPOSITION.txt
# DISSENTING OPINION.txt
# FINDINGS1.txt
# FINDINGS2.txt
# FINDINGS3.txt
# FINDINGS4.txt
# FINDINGS5.txt
# FINDINGS6.txt
# FINDINGS7.txt
# FINDINGS8.txt
# INTRO.txt
# LAW.txt
# MILITARY STRUCTURE.txt
# POLITICAL STRUCTURE.txt
# REQUIREMENTS.txt
# RESPONSIBILITY1.txt
# RESPONSIBILITY2_BRIMA.txt
# RESPONSIBILITY3_KAMARA.txt
# RESPONSIBILITY4_KANU.txt
# ROLE 3_KANU.txt
# ROLE1_BRIMA.txt
# ROLE2_KAMARA.txt

# %%
ALL_CASE_DATA_model = create_lda_model(ALL_CASE_DATA, case="default", num_topics=10, iterations=5000, save=True)
# Out:
# saving as All Cases_10_topics_11h39m

# %%
def analyze_file(lda_model, file):
    """
    creates dictionaries and transforms the file to the valid gensim format for LDA,
    and analyzes it
    :param lda_model: the model according to
    :param file:
    :return:
    """
    dct = Dictionary([file])  # fit dictionary
    bow = dct.doc2bow(file)
    doc_lda = lda_model[bow]
    doc_lda.sort(key=lambda x: x[1], reverse=True)
    print(doc_lda)
    return doc_lda

# %%
def save_processed_files(file_list, doc_name, processed_folders_path):
    """
    save the clean and lemmatized files into a single text file - relevant for the topic
    modeling, not for the topic dist
    :param
    file_list the list of processed files
    """
    f = open(processed_folders_path + "\\" + doc_name + ".txt", "w")
    for file in file_list:
        for word in file:
            f.write(word)
            f.write(" ")
        f.write("\n")
    f.close()

# %%
save_processed_files(ALL_CASE_DATA,"all_cases",processed_folders_path)

# %%
def get_distributions(model):
    folders = []
    num_files = 0
    for name in LDA_modeler.names:
        folders.append(LDA_modeler.upload_from_file(name, LDA_modeler.PROCESSED_FILES_FOLDER))
        distribution_f = open(DIST_PATH, "w")
    for folder in folders:
        for file in folder:
            num_files += 1
            print(file)
            dist = LDA_modeler.analyze_file(model, file)
            distribution_f.write(", ".join(file))
            distribution_f.write("\n")
            str_dist = [str(dist[i][0]) + " - " + str(dist[i][1]) for i in range(len(dist))]
            distribution_f.write(", ".join(str_dist))
            distribution_f.write("\n")
    return num_files

# %%
print(STOP_WORDS_PATH)
# Out:
# C:\stopwords\updated_stop_words.txt

# %%
import LDA_modeler
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-b4fbd7d5b6eb> in <module>()
# ----> 1 import LDA_modeler
#
# ~\OneDrive\NUS\Year 3\Sem 2\RA\Martin Buber\LDA_modeler.py in <module>()
#      34 SPECIAL_WORDS = ["was", "us", "as", "less", "has", "media", "Serbs", "muslims", "raped", "man", "commander", "worked",
#      35                  "men", "does", "gave", "happened", "commander", "heard", "judes", "fo"]
# ---> 36 stop_words = [token.strip("\n") for token in open(STOP_WORDS_PATH, "r")]
#      37
#      38
#
# NameError: name 'STOP_WORDS_PATH' is not defined
